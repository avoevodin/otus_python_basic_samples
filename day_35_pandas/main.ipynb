# %%
import pandas as pd

# %%
salaries_list = [
    165.5,
    234.8,
    211.1,
    455.3,
    152.9,
    532.7,
]

# %%
salaries_series = pd.Series(salaries_list)
print(salaries_series)
print(type(salaries_series))
# Out:
# 0    165.5
# 1    234.8
# 2    211.1
# 3    455.3
# 4    152.9
# 5    532.7
# dtype: float64
# <class 'pandas.core.series.Series'>

# %%
print(salaries_series.to_list())
print(salaries_series.to_numpy())
# Out:
# [165.5, 234.8, 211.1, 455.3, 152.9, 532.7]
# [165.5 234.8 211.1 455.3 152.9 532.7]

# %%
workers_names = [
    "John",
    "Kate",
    "Sam",
    "Nick",
    "Clark",
    "Ann",
]

# %%
salaries = pd.Series(
    salaries_list,
    index=workers_names,
    name="Salaries",
)
print(salaries)
# Out:
# John     165.5
# Kate     234.8
# Sam      211.1
# Nick     455.3
# Clark    152.9
# Ann      532.7
# Name: Salaries, dtype: float64

# %%
print(salaries["John"])
print(salaries[0])
# Out:
# 165.5
# 165.5

# %%
print(salaries.index)
print(salaries_series.index)
# Out:
# Index(['John', 'Kate', 'Sam', 'Nick', 'Clark', 'Ann'], dtype='object')
# RangeIndex(start=0, stop=6, step=1)

# %%
print(salaries[1:3])
print(salaries_series[2:4])
print(salaries["Sam":"Ann"])
print(salaries[:"Nick"])
# Out:
# Kate    234.8
# Sam     211.1
# Name: Salaries, dtype: float64
# 2    211.1
# 3    455.3
# dtype: float64
# Sam      211.1
# Nick     455.3
# Clark    152.9
# Ann      532.7
# Name: Salaries, dtype: float64
# John    165.5
# Kate    234.8
# Sam     211.1
# Nick    455.3
# Name: Salaries, dtype: float64

# %%
print(salaries.mean())
print(salaries.median())
# Out:
# 292.05
# 222.95

# %%
print(salaries.value_counts())
print(salaries.value_counts(normalize=True))
# Out:
# 165.5    1
# 234.8    1
# 211.1    1
# 455.3    1
# 152.9    1
# 532.7    1
# Name: Salaries, dtype: int64
# 165.5    0.166667
# 234.8    0.166667
# 211.1    0.166667
# 455.3    0.166667
# 152.9    0.166667
# 532.7    0.166667
# Name: Salaries, dtype: float64

# %%
print(pd.Series([1,2,3,2,3,4,5,2,1,1,6]).value_counts())
print(pd.Series([1,2,3,2,3,4,5,2,1,1,6]).value_counts(normalize=True))
# Out:
# 1    3
# 2    3
# 3    2
# 4    1
# 5    1
# 6    1
# dtype: int64
# 1    0.272727
# 2    0.272727
# 3    0.181818
# 4    0.090909
# 5    0.090909
# 6    0.090909
# dtype: float64

# %%
s = salaries.copy()
print(s == salaries)
print(s is salaries)
# Out:
# John     True
# Kate     True
# Sam      True
# Nick     True
# Clark    True
# Ann      True
# Name: Salaries, dtype: bool
# False

# %%
s.reset_index()
# Out:
#    index  Salaries
# 0   John     165.5
# 1   Kate     234.8
# 2    Sam     211.1
# 3   Nick     455.3
# 4  Clark     152.9
# 5    Ann     532.7

# %%
s.reset_index(drop=True, inplace=True)
s
# Out:
# 0    165.5
# 1    234.8
# 2    211.1
# 3    455.3
# 4    152.9
# 5    532.7
# Name: Salaries, dtype: float64

# %%
salaries.describe()
# Out:
# count      6.000000
# mean     292.050000
# std      161.103119
# min      152.900000
# 25%      176.900000
# 50%      222.950000
# 75%      400.175000
# max      532.700000
# Name: Salaries, dtype: float64

# %%
salaries.to_json()
# Out:
# '{"John":165.5,"Kate":234.8,"Sam":211.1,"Nick":455.3,"Clark":152.9,"Ann":532.7}'

# %%
# salaries.to_sql()

# %%
# salaries.to_excel()

# %%
workers_salaries = [
    {
        "name": "John",
        "salary": 169.5,
        "age": 18,
    },
    {
        "name": "Sam",
        "salary": 234.7,
        "age": 27,
    }, 
    {
        "name": "Bob",
        "salary": 158.3,
        "age": 33,
    },
]
salaries_df = pd.DataFrame(workers_salaries)
salaries_df
# Out:
#    name  salary  age
# 0  John   169.5   18
# 1   Sam   234.7   27
# 2   Bob   158.3   33

# %%
salaries_df["name"][0]
# Out:
# 'John'

# %%
help(salaries.iloc())
# Out:
# Help on _iLocIndexer in module pandas.core.indexing object:
#
# class _iLocIndexer(_LocationIndexer)
#  |  Purely integer-location based indexing for selection by position.
#  |
#  |  ``.iloc[]`` is primarily integer position based (from ``0`` to
#  |  ``length-1`` of the axis), but may also be used with a boolean
#  |  array.
#  |
#  |  Allowed inputs are:
#  |
#  |  - An integer, e.g. ``5``.
#  |  - A list or array of integers, e.g. ``[4, 3, 0]``.
#  |  - A slice object with ints, e.g. ``1:7``.
#  |  - A boolean array.
#  |  - A ``callable`` function with one argument (the calling Series or
#  |    DataFrame) and that returns valid output for indexing (one of the above).
#  |    This is useful in method chains, when you don't have a reference to the
#  |    calling object, but would like to base your selection on some value.
#  |
#  |  ``.iloc`` will raise ``IndexError`` if a requested indexer is
#  |  out-of-bounds, except *slice* indexers which allow out-of-bounds
#  |  indexing (this conforms with python/numpy *slice* semantics).
#  |
#  |  See more at :ref:`Selection by Position <indexing.integer>`.
#  |
#  |  See Also
#  |  --------
#  |  DataFrame.iat : Fast integer location scalar accessor.
#  |  DataFrame.loc : Purely label-location based indexer for selection by label.
#  |  Series.iloc : Purely integer-location based indexing for
#  |                 selection by position.
#  |
#  |  Examples
#  |  --------
#  |  >>> mydict = [{'a': 1, 'b': 2, 'c': 3, 'd': 4},
#  |  ...           {'a': 100, 'b': 200, 'c': 300, 'd': 400},
#  |  ...           {'a': 1000, 'b': 2000, 'c': 3000, 'd': 4000 }]
#  |  >>> df = pd.DataFrame(mydict)
#  |  >>> df
#  |        a     b     c     d
#  |  0     1     2     3     4
#  |  1   100   200   300   400
#  |  2  1000  2000  3000  4000
#  |
#  |  **Indexing just the rows**
#  |
#  |  With a scalar integer.
#  |
#  |  >>> type(df.iloc[0])
#  |  <class 'pandas.core.series.Series'>
#  |  >>> df.iloc[0]
#  |  a    1
#  |  b    2
#  |  c    3
#  |  d    4
#  |  Name: 0, dtype: int64
#  |
#  |  With a list of integers.
#  |
#  |  >>> df.iloc[[0]]
#  |     a  b  c  d
#  |  0  1  2  3  4
#  |  >>> type(df.iloc[[0]])
#  |  <class 'pandas.core.frame.DataFrame'>
#  |
#  |  >>> df.iloc[[0, 1]]
#  |       a    b    c    d
#  |  0    1    2    3    4
#  |  1  100  200  300  400
#  |
#  |  With a `slice` object.
#  |
#  |  >>> df.iloc[:3]
#  |        a     b     c     d
#  |  0     1     2     3     4
#  |  1   100   200   300   400
#  |  2  1000  2000  3000  4000
#  |
#  |  With a boolean mask the same length as the index.
#  |
#  |  >>> df.iloc[[True, False, True]]
#  |        a     b     c     d
#  |  0     1     2     3     4
#  |  2  1000  2000  3000  4000
#  |
#  |  With a callable, useful in method chains. The `x` passed
#  |  to the ``lambda`` is the DataFrame being sliced. This selects
#  |  the rows whose index label even.
#  |
#  |  >>> df.iloc[lambda x: x.index % 2 == 0]
#  |        a     b     c     d
#  |  0     1     2     3     4
#  |  2  1000  2000  3000  4000
#  |
#  |  **Indexing both axes**
#  |
#  |  You can mix the indexer types for the index and columns. Use ``:`` to
#  |  select the entire axis.
#  |
#  |  With scalar integers.
#  |
#  |  >>> df.iloc[0, 1]
#  |  2
#  |
#  |  With lists of integers.
#  |
#  |  >>> df.iloc[[0, 2], [1, 3]]
#  |        b     d
#  |  0     2     4
#  |  2  2000  4000
#  |
#  |  With `slice` objects.
#  |
#  |  >>> df.iloc[1:3, 0:3]
#  |        a     b     c
#  |  1   100   200   300
#  |  2  1000  2000  3000
#  |
#  |  With a boolean array whose length matches the columns.
#  |
#  |  >>> df.iloc[:, [True, False, True, False]]
#  |        a     c
#  |  0     1     3
#  |  1   100   300
#  |  2  1000  3000
#  |
#  |  With a callable function that expects the Series or DataFrame.
#  |
#  |  >>> df.iloc[:, lambda df: [0, 2]]
#  |        a     c
#  |  0     1     3
#  |  1   100   300
#  |  2  1000  3000
#  |
#  |  Method resolution order:
#  |      _iLocIndexer
#  |      _LocationIndexer
#  |      pandas._libs.indexing.NDFrameIndexerBase
#  |      builtins.object
#  |
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {}
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from _LocationIndexer:
#  |
#  |  __call__(self, axis=None)
#  |      Call self as a function.
#  |
#  |  __getitem__(self, key)
#  |
#  |  __setitem__(self, key, value)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from _LocationIndexer:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from _LocationIndexer:
#  |
#  |  axis = None
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from pandas._libs.indexing.NDFrameIndexerBase:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __reduce__ = __reduce_cython__(...)
#  |
#  |  __setstate__ = __setstate_cython__(...)
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from pandas._libs.indexing.NDFrameIndexerBase:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from pandas._libs.indexing.NDFrameIndexerBase:
#  |
#  |  name
#  |
#  |  ndim
#  |
#  |  obj

# %%
help(salaries.loc())
# Out:
# Help on _LocIndexer in module pandas.core.indexing object:
#
# class _LocIndexer(_LocationIndexer)
#  |  Access a group of rows and columns by label(s) or a boolean array.
#  |
#  |  ``.loc[]`` is primarily label based, but may also be used with a
#  |  boolean array.
#  |
#  |  Allowed inputs are:
#  |
#  |  - A single label, e.g. ``5`` or ``'a'``, (note that ``5`` is
#  |    interpreted as a *label* of the index, and **never** as an
#  |    integer position along the index).
#  |  - A list or array of labels, e.g. ``['a', 'b', 'c']``.
#  |  - A slice object with labels, e.g. ``'a':'f'``.
#  |
#  |    .. warning:: Note that contrary to usual python slices, **both** the
#  |        start and the stop are included
#  |
#  |  - A boolean array of the same length as the axis being sliced,
#  |    e.g. ``[True, False, True]``.
#  |  - An alignable boolean Series. The index of the key will be aligned before
#  |    masking.
#  |  - An alignable Index. The Index of the returned selection will be the input.
#  |  - A ``callable`` function with one argument (the calling Series or
#  |    DataFrame) and that returns valid output for indexing (one of the above)
#  |
#  |  See more at :ref:`Selection by Label <indexing.label>`.
#  |
#  |  Raises
#  |  ------
#  |  KeyError
#  |      If any items are not found.
#  |  IndexingError
#  |      If an indexed key is passed and its index is unalignable to the frame index.
#  |
#  |  See Also
#  |  --------
#  |  DataFrame.at : Access a single value for a row/column label pair.
#  |  DataFrame.iloc : Access group of rows and columns by integer position(s).
#  |  DataFrame.xs : Returns a cross-section (row(s) or column(s)) from the
#  |      Series/DataFrame.
#  |  Series.loc : Access group of values using labels.
#  |
#  |  Examples
#  |  --------
#  |  **Getting values**
#  |
#  |  >>> df = pd.DataFrame([[1, 2], [4, 5], [7, 8]],
#  |  ...      index=['cobra', 'viper', 'sidewinder'],
#  |  ...      columns=['max_speed', 'shield'])
#  |  >>> df
#  |              max_speed  shield
#  |  cobra               1       2
#  |  viper               4       5
#  |  sidewinder          7       8
#  |
#  |  Single label. Note this returns the row as a Series.
#  |
#  |  >>> df.loc['viper']
#  |  max_speed    4
#  |  shield       5
#  |  Name: viper, dtype: int64
#  |
#  |  List of labels. Note using ``[[]]`` returns a DataFrame.
#  |
#  |  >>> df.loc[['viper', 'sidewinder']]
#  |              max_speed  shield
#  |  viper               4       5
#  |  sidewinder          7       8
#  |
#  |  Single label for row and column
#  |
#  |  >>> df.loc['cobra', 'shield']
#  |  2
#  |
#  |  Slice with labels for row and single label for column. As mentioned
#  |  above, note that both the start and stop of the slice are included.
#  |
#  |  >>> df.loc['cobra':'viper', 'max_speed']
#  |  cobra    1
#  |  viper    4
#  |  Name: max_speed, dtype: int64
#  |
#  |  Boolean list with the same length as the row axis
#  |
#  |  >>> df.loc[[False, False, True]]
#  |              max_speed  shield
#  |  sidewinder          7       8
#  |
#  |  Alignable boolean Series:
#  |
#  |  >>> df.loc[pd.Series([False, True, False],
#  |  ...        index=['viper', 'sidewinder', 'cobra'])]
#  |              max_speed  shield
#  |  sidewinder          7       8
#  |
#  |  Index (same behavior as ``df.reindex``)
#  |
#  |  >>> df.loc[pd.Index(["cobra", "viper"], name="foo")]
#  |         max_speed  shield
#  |  foo
#  |  cobra          1       2
#  |  viper          4       5
#  |
#  |  Conditional that returns a boolean Series
#  |
#  |  >>> df.loc[df['shield'] > 6]
#  |              max_speed  shield
#  |  sidewinder          7       8
#  |
#  |  Conditional that returns a boolean Series with column labels specified
#  |
#  |  >>> df.loc[df['shield'] > 6, ['max_speed']]
#  |              max_speed
#  |  sidewinder          7
#  |
#  |  Callable that returns a boolean Series
#  |
#  |  >>> df.loc[lambda df: df['shield'] == 8]
#  |              max_speed  shield
#  |  sidewinder          7       8
#  |
#  |  **Setting values**
#  |
#  |  Set value for all items matching the list of labels
#  |
#  |  >>> df.loc[['viper', 'sidewinder'], ['shield']] = 50
#  |  >>> df
#  |              max_speed  shield
#  |  cobra               1       2
#  |  viper               4      50
#  |  sidewinder          7      50
#  |
#  |  Set value for an entire row
#  |
#  |  >>> df.loc['cobra'] = 10
#  |  >>> df
#  |              max_speed  shield
#  |  cobra              10      10
#  |  viper               4      50
#  |  sidewinder          7      50
#  |
#  |  Set value for an entire column
#  |
#  |  >>> df.loc[:, 'max_speed'] = 30
#  |  >>> df
#  |              max_speed  shield
#  |  cobra              30      10
#  |  viper              30      50
#  |  sidewinder         30      50
#  |
#  |  Set value for rows matching callable condition
#  |
#  |  >>> df.loc[df['shield'] > 35] = 0
#  |  >>> df
#  |              max_speed  shield
#  |  cobra              30      10
#  |  viper               0       0
#  |  sidewinder          0       0
#  |
#  |  **Getting values on a DataFrame with an index that has integer labels**
#  |
#  |  Another example using integers for the index
#  |
#  |  >>> df = pd.DataFrame([[1, 2], [4, 5], [7, 8]],
#  |  ...      index=[7, 8, 9], columns=['max_speed', 'shield'])
#  |  >>> df
#  |     max_speed  shield
#  |  7          1       2
#  |  8          4       5
#  |  9          7       8
#  |
#  |  Slice with integer labels for rows. As mentioned above, note that both
#  |  the start and stop of the slice are included.
#  |
#  |  >>> df.loc[7:9]
#  |     max_speed  shield
#  |  7          1       2
#  |  8          4       5
#  |  9          7       8
#  |
#  |  **Getting values with a MultiIndex**
#  |
#  |  A number of examples using a DataFrame with a MultiIndex
#  |
#  |  >>> tuples = [
#  |  ...    ('cobra', 'mark i'), ('cobra', 'mark ii'),
#  |  ...    ('sidewinder', 'mark i'), ('sidewinder', 'mark ii'),
#  |  ...    ('viper', 'mark ii'), ('viper', 'mark iii')
#  |  ... ]
#  |  >>> index = pd.MultiIndex.from_tuples(tuples)
#  |  >>> values = [[12, 2], [0, 4], [10, 20],
#  |  ...         [1, 4], [7, 1], [16, 36]]
#  |  >>> df = pd.DataFrame(values, columns=['max_speed', 'shield'], index=index)
#  |  >>> df
#  |                       max_speed  shield
#  |  cobra      mark i           12       2
#  |             mark ii           0       4
#  |  sidewinder mark i           10      20
#  |             mark ii           1       4
#  |  viper      mark ii           7       1
#  |             mark iii         16      36
#  |
#  |  Single label. Note this returns a DataFrame with a single index.
#  |
#  |  >>> df.loc['cobra']
#  |           max_speed  shield
#  |  mark i          12       2
#  |  mark ii          0       4
#  |
#  |  Single index tuple. Note this returns a Series.
#  |
#  |  >>> df.loc[('cobra', 'mark ii')]
#  |  max_speed    0
#  |  shield       4
#  |  Name: (cobra, mark ii), dtype: int64
#  |
#  |  Single label for row and column. Similar to passing in a tuple, this
#  |  returns a Series.
#  |
#  |  >>> df.loc['cobra', 'mark i']
#  |  max_speed    12
#  |  shield        2
#  |  Name: (cobra, mark i), dtype: int64
#  |
#  |  Single tuple. Note using ``[[]]`` returns a DataFrame.
#  |
#  |  >>> df.loc[[('cobra', 'mark ii')]]
#  |                 max_speed  shield
#  |  cobra mark ii          0       4
#  |
#  |  Single tuple for the index with a single label for the column
#  |
#  |  >>> df.loc[('cobra', 'mark i'), 'shield']
#  |  2
#  |
#  |  Slice from index tuple to single label
#  |
#  |  >>> df.loc[('cobra', 'mark i'):'viper']
#  |                       max_speed  shield
#  |  cobra      mark i           12       2
#  |             mark ii           0       4
#  |  sidewinder mark i           10      20
#  |             mark ii           1       4
#  |  viper      mark ii           7       1
#  |             mark iii         16      36
#  |
#  |  Slice from index tuple to index tuple
#  |
#  |  >>> df.loc[('cobra', 'mark i'):('viper', 'mark ii')]
#  |                      max_speed  shield
#  |  cobra      mark i          12       2
#  |             mark ii          0       4
#  |  sidewinder mark i          10      20
#  |             mark ii          1       4
#  |  viper      mark ii          7       1
#  |
#  |  Method resolution order:
#  |      _LocIndexer
#  |      _LocationIndexer
#  |      pandas._libs.indexing.NDFrameIndexerBase
#  |      builtins.object
#  |
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {'_takeable': 'bool'}
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from _LocationIndexer:
#  |
#  |  __call__(self, axis=None)
#  |      Call self as a function.
#  |
#  |  __getitem__(self, key)
#  |
#  |  __setitem__(self, key, value)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from _LocationIndexer:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from _LocationIndexer:
#  |
#  |  axis = None
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from pandas._libs.indexing.NDFrameIndexerBase:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __reduce__ = __reduce_cython__(...)
#  |
#  |  __setstate__ = __setstate_cython__(...)
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from pandas._libs.indexing.NDFrameIndexerBase:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from pandas._libs.indexing.NDFrameIndexerBase:
#  |
#  |  name
#  |
#  |  ndim
#  |
#  |  obj

# %%
print(salaries["Nick":"Ann"])
print(salaries.loc["Nick":"Ann"])
print(salaries.iloc[3:5])
# Out:
# Nick     455.3
# Clark    152.9
# Ann      532.7
# Name: Salaries, dtype: float64
# Nick     455.3
# Clark    152.9
# Ann      532.7
# Name: Salaries, dtype: float64
# Nick     455.3
# Clark    152.9
# Name: Salaries, dtype: float64

# %%
salaries_df.index = ["j", "s", "b"]

# %%
salaries_df
# Out:
#    name  salary  age
# j  John   169.5   18
# s   Sam   234.7   27
# b   Bob   158.3   33

# %%
salaries_df.loc['j']
salaries_df.loc['j':"s"]
# Out:
#    name  salary  age
# j  John   169.5   18
# s   Sam   234.7   27

# %%
salaries_df.to_json()
salaries_df.to_json('sararies.json')

# %%
salaries_df.to_csv('data/salaries.csv')

# %%
pd.read_csv('data/salaries.csv')
# Out:
#   Unnamed: 0  name  salary  age
# 0          j  John   169.5   18
# 1          s   Sam   234.7   27
# 2          b   Bob   158.3   33

# %%
pd.read_csv('data/salaries.csv', index_col=0)
# Out:
#    name  salary  age
# j  John   169.5   18
# s   Sam   234.7   27
# b   Bob   158.3   33

# %%
salaries_df.to_dict()
# Out:
# {'name': {'j': 'John', 's': 'Sam', 'b': 'Bob'},
#  'salary': {'j': 169.5, 's': 234.7, 'b': 158.3},
#  'age': {'j': 18, 's': 27, 'b': 33}}

# %%
for item in salaries_df.iterrows():
    print(item)
# Out:
# ('j', name       John
# salary    169.5
# age          18
# Name: j, dtype: object)
# ('s', name        Sam
# salary    234.7
# age          27
# Name: s, dtype: object)
# ('b', name        Bob
# salary    158.3
# age          33
# Name: b, dtype: object)

# %%
for idx, row in salaries_df.iterrows():
    print(idx, row.age, row.name, row["name"])
    print(row)
    print(type(row))
# Out:
# j 18 j John
# name       John
# salary    169.5
# age          18
# Name: j, dtype: object
# <class 'pandas.core.series.Series'>
# s 27 s Sam
# name        Sam
# salary    234.7
# age          27
# Name: s, dtype: object
# <class 'pandas.core.series.Series'>
# b 33 b Bob
# name        Bob
# salary    158.3
# age          33
# Name: b, dtype: object
# <class 'pandas.core.series.Series'>

# %%
salaries_df.loc['s':'b', 'salary']
# Out:
# s    234.7
# b    158.3
# Name: salary, dtype: float64

# %%
salaries_df.loc['s':'b', ['name', 'salary']]
# Out:
#   name  salary
# s  Sam   234.7
# b  Bob   158.3

# %%
countries_info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 countries_info
#
# NameError: name 'countries_info' is not defined

# %%
titanic_df = pd.read_csv('data/titanic.csv')
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 10)

# %%
titanic_df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex  ...  Parch            Ticket     Fare Cabin  Embarked
# 881    male  ...      0            349257   7.8958   NaN         S
# 882  female  ...      0              7552  10.5167   NaN         S
# 883    male  ...      0  C.A./SOTON 34068  10.5000   NaN         S
# 884    male  ...      0   SOTON/OQ 392076   7.0500   NaN         S
# 885  female  ...      5            382652  29.1250   NaN         Q
# 886    male  ...      0            211536  13.0000   NaN         S
# 887  female  ...      0            112053  30.0000   B42         S
# 888  female  ...      2        W./C. 6607  23.4500   NaN         S
# 889    male  ...      0            111369  30.0000  C148         C
# 890    male  ...      0            370376   7.7500   NaN         Q
#
# [10 rows x 12 columns]

# %%
titanic_df.head(10)

# %%
titanic_df.info()

# %%
titanic_df.describe()

# %%
titanic_df.columns

# %%
df = titanic_df

# %%
df['Pclass'].value_counts()

# %%
df['Pclass'].value_counts(normalize=True)

# %%
df.loc[df['Age'] < 1]['Age']

# %%
df.value_counts('Sex')

# %%
df.value_counts('Age')

# %%
df.groupby('Sex').count()

# %%
df.groupby('Sex').mean()

# %%
df.groupby('Sex')['Age'].median()

# %%
df.groupby(['Sex','Survived'])['PassengerId'].count()

# %%
df.groupby(['Sex','Survived'])['Age'].median()

# %%
df.pivot_table(
    index=['Sex'],
    columns=['Pclass'],
    values=['Age'],
    aggfunc='median' 
)

# %%
df.pivot_table(
    index=['Sex'],
    columns=['Pclass','Survived'],
    values=['Age'],
    aggfunc='median' 
)
# Out:
#            Age
# Pclass       1           2           3
# Survived     0     1     0     1     0     1
# Sex
# female    25.0  35.0  32.5  28.0  22.0  19.0
# male      45.5  36.0  30.5   3.0  25.0  25.0

# %%
weights_df = pd.read_csv('data/weights.csv', index_col=0, parse_dates=True)
weights_df
# Out:
#             AT0000A18XM4 SW  BE0974268972 BB  US0527691069 US  \
# 2014-01-14         0.184660         0.275706         0.303425
# 2014-01-15         0.225875         0.147861         0.151211
# 2014-01-16         0.261017         0.334213         0.293336
# 2014-01-17         0.160168         0.231034         0.092674
# 2014-01-18         0.057162         0.254146         0.027286
# ...                     ...              ...              ...
# 2018-02-28         0.123821         0.167899         0.120844
# 2018-03-01         0.035043         0.289624         0.220871
# 2018-03-02         0.397155         0.362025         0.050554
# 2018-03-03         0.319902         0.277405         0.051719
# 2018-03-06         0.057699         0.352290         0.291162
#
#             DE0007164600 GR  US6092071058 US
# 2014-01-14         0.042841         0.193368
# 2014-01-15         0.224074         0.250978
# 2014-01-16         0.015744         0.095690
# 2014-01-17         0.269050         0.247074
# 2014-01-18         0.480660         0.180746
# ...                     ...              ...
# 2018-02-28         0.088780         0.498657
# 2018-03-01         0.136366         0.318096
# 2018-03-02         0.020247         0.170019
# 2018-03-03         0.008164         0.342810
# 2018-03-06         0.197700         0.101148
#
# [1081 rows x 5 columns]

# %%
weights_df.sort_index(ascending=False)
# Out:
#             AT0000A18XM4 SW  BE0974268972 BB  US0527691069 US  \
# 2018-03-06         0.057699         0.352290         0.291162
# 2018-03-03         0.319902         0.277405         0.051719
# 2018-03-02         0.397155         0.362025         0.050554
# 2018-03-01         0.035043         0.289624         0.220871
# 2018-02-28         0.123821         0.167899         0.120844
# ...                     ...              ...              ...
# 2014-01-18         0.057162         0.254146         0.027286
# 2014-01-17         0.160168         0.231034         0.092674
# 2014-01-16         0.261017         0.334213         0.293336
# 2014-01-15         0.225875         0.147861         0.151211
# 2014-01-14         0.184660         0.275706         0.303425
#
#             DE0007164600 GR  US6092071058 US
# 2018-03-06         0.197700         0.101148
# 2018-03-03         0.008164         0.342810
# 2018-03-02         0.020247         0.170019
# 2018-03-01         0.136366         0.318096
# 2018-02-28         0.088780         0.498657
# ...                     ...              ...
# 2014-01-18         0.480660         0.180746
# 2014-01-17         0.269050         0.247074
# 2014-01-16         0.015744         0.095690
# 2014-01-15         0.224074         0.250978
# 2014-01-14         0.042841         0.193368
#
# [1081 rows x 5 columns]

# %%
df = weights_df

# %%
df.columns
# Out:
# Index(['AT0000A18XM4 SW', 'BE0974268972 BB', 'US0527691069 US',
#        'DE0007164600 GR', 'US6092071058 US'],
#       dtype='object')

# %%
df['AT0000A18XM4 SW']
# Out:
# 2014-01-14    0.184660
# 2014-01-15    0.225875
# 2014-01-16    0.261017
# 2014-01-17    0.160168
# 2014-01-18    0.057162
#                 ...
# 2018-02-28    0.123821
# 2018-03-01    0.035043
# 2018-03-02    0.397155
# 2018-03-03    0.319902
# 2018-03-06    0.057699
# Name: AT0000A18XM4 SW, Length: 1081, dtype: float64

# %%
df.agg(['min', 'max', 'mean', 'median'])
# Out:
#         AT0000A18XM4 SW  BE0974268972 BB  US0527691069 US  DE0007164600 GR  \
# min            0.000063         0.000018         0.000331     2.895741e-07
# max            0.588783         0.638583         0.792982     8.555499e-01
# mean           0.192054         0.203109         0.204913     2.009432e-01
# median         0.188876         0.201496         0.200618     1.987364e-01
#
#         US6092071058 US
# min            0.000132
# max            0.621904
# mean           0.198981
# median         0.204044

# %%
df.idxmax()
# Out:
# AT0000A18XM4 SW   2017-05-06
# BE0974268972 BB   2014-10-08
# US0527691069 US   2017-08-24
# DE0007164600 GR   2017-01-25
# US6092071058 US   2016-06-15
# dtype: datetime64[ns]

# %%
df.idxmin()
# Out:
# AT0000A18XM4 SW   2015-03-14
# BE0974268972 BB   2015-07-04
# US0527691069 US   2016-04-20
# DE0007164600 GR   2018-01-23
# US6092071058 US   2015-08-21
# dtype: datetime64[ns]

# %%
df.loc[df.idxmax()]
# Out:
#             AT0000A18XM4 SW  BE0974268972 BB  US0527691069 US  \
# 2017-05-06         0.588783         0.098971         0.065059
# 2014-10-08         0.055022         0.638583         0.087784
# 2017-08-24         0.016481         0.081014         0.792982
# 2017-01-25         0.033026         0.044487         0.063948
# 2016-06-15         0.089216         0.227885         0.007397
#
#             DE0007164600 GR  US6092071058 US
# 2017-05-06         0.220716         0.026471
# 2014-10-08         0.004366         0.214245
# 2017-08-24         0.034498         0.075025
# 2017-01-25         0.855550         0.002989
# 2016-06-15         0.053598         0.621904

# %%
df.loc[df.idxmin()]
# Out:
#             AT0000A18XM4 SW  BE0974268972 BB  US0527691069 US  \
# 2015-03-14         0.000063         0.426246         0.013127
# 2015-07-04         0.041093         0.000018         0.390096
# 2016-04-20         0.178660         0.372705         0.000331
# 2018-01-23         0.114776         0.064787         0.622151
# 2015-08-21         0.101986         0.206050         0.344479
#
#             DE0007164600 GR  US6092071058 US
# 2015-03-14     3.071502e-01         0.253414
# 2015-07-04     2.017649e-01         0.367028
# 2016-04-20     4.105506e-01         0.037754
# 2018-01-23     2.895741e-07         0.198286
# 2015-08-21     3.473532e-01         0.000132

# %%
import json

# %%
with open('data/fines.json', 'r') as f:
    fines_data = json.load(f)
fines_data.keys()
# Out:
# dict_keys(['Message', 'ShowMessage', 'StateCode', 'TimeStamp', 'Value'])

# %%
fines_values = json.loads(fines_data['Value'])['Fines']
fines_values
# Out:
# [{'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': 0,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.17 ч.1.2 - Движение или остановка на полосе для маршрутных ТС в Москве или в Санкт-Петербурге'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '23.01.2018 00:21:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   МОХОВАЯ д.15/1'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'}],
#   'DAP': '18810177180125209293',
#   'DAPName': 'Постановление по видеофиксации №18810177180125209293 от 25.01.2018',
#   'DateDAP': '25.01.2018',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 3000,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,7563209999',
#   'Longitude': '37,614136',
#   'OdpsKod': '1145519',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177180125209293","DateDAP":"25.01.2018","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":3000,"Uin":"18810177180125209293"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': 'f9e58750-5f64-4138-942a-67e0967d4547',
#   'VidNak': '2',
#   'VstupDate': '',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.09.2 - Превышение скорости движения ТС от 20 до 40 км/ч'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'БОЛЬШИЕ ВЯЗЕМЫ РП,ЯМСКАЯ,д.1,стр.1,ОДИНЦОВСКИЙ Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '10.09.2017 10:31:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': '  А/Д М-9 "БАЛТИЯ", 24КМ+750М, ИЗ МОСКВЫ'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'Центр видеофиксации ГИБДД ГУ МВД России по Московской области'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '27.10.2017'}],
#   'DAP': '18810150170911043896',
#   'DAPName': 'Постановление по видеофиксации №18810150170911043896 от 11.09.2017',
#   'DateDAP': '11.09.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 500,
#   'HasAdditionalActions': False,
#   'HasPhoto': False,
#   'IsFine': True,
#   'Latitude': '55,7911569999',
#   'Longitude': '37,260069',
#   'OdpsKod': '1146511',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810150170911043896","DateDAP":"11.09.2017","ODPS":"Центр видеофиксации ГИБДД ГУ МВД России по Московской области","PaymentID":null,"RsRschet":"40101810845250010102","SgBuk":"044525000","ShBankName":"ГУ банка России по ЦФО","ShInn":"7703037039","ShKbk":"18811630020016000140","ShKpp":"770245001","ShOkato":"46641152","ShPoluchName":"УФК по МО (УГИБДД ГУ МВД РОССИИ по МО)","Sum":500,"Uin":"18810150170911043896"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': '3e4c491f-df4e-4fad-99df-c08c3b4caef3',
#   'VidNak': '2',
#   'VstupDate': '27.10.2017',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.9.6 - Повторное превышение скорости на 40-60 км/час'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '24.07.2017 10:19:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   РУБЛЕВСКОЕ Ш. д.79'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '12.09.2017'}],
#   'DAP': '18810177170728394158',
#   'DAPName': 'Постановление по видеофиксации №18810177170728394158 от 28.07.2017',
#   'DateDAP': '28.07.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 2000,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,7391939999',
#   'Longitude': '37,433588',
#   'OdpsKod': '1145519',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177170728394158","DateDAP":"28.07.2017","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":2000,"Uin":"18810177170728394158"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': '56a49c82-c13d-4863-928a-dc8d5c5ca143',
#   'VidNak': '2',
#   'VstupDate': '12.09.2017',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.15.1 - Наруш.правил расп.т/с на пр.части без выезда на ст.встр.движ.,дв.по обоч.,пересечение колонны'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '20.06.2017 00:07:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   КУТУЗОВСКИЙ ПРОСП.'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '05.08.2017'}],
#   'DAP': '18810177170621061208',
#   'DAPName': 'Постановление по видеофиксации №18810177170621061208 от 21.06.2017',
#   'DateDAP': '21.06.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 1500,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,732458',
#   'Longitude': '37,496129',
#   'OdpsKod': '1145519',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177170621061208","DateDAP":"21.06.2017","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":1500,"Uin":"18810177170621061208"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': '5f5e4047-269d-45a3-b545-cee540dc4a51',
#   'VidNak': '2',
#   'VstupDate': '05.08.2017',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.9.6 - Повторное превышение скорости на 40-60 км/час'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '22.06.2017 19:47:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   НОВЫЙ АРБАТ д.36/9'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '16.08.2017'}],
#   'DAP': '18810177170702113941',
#   'DAPName': 'Постановление по видеофиксации №18810177170702113941 от 02.07.2017',
#   'DateDAP': '02.07.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 2000,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,752697',
#   'Longitude': '37,577857',
#   'OdpsKod': '1145519',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177170702113941","DateDAP":"02.07.2017","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":2000,"Uin":"18810177170702113941"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': 'fac605aa-59e7-4f40-878a-ed4d05538ad7',
#   'VidNak': '2',
#   'VstupDate': '16.08.2017',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.15.1 - Наруш.правил расп.т/с на пр.части без выезда на ст.встр.движ.,дв.по обоч.,пересечение колонны'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '13.07.2017 11:47:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   КУТУЗОВСКИЙ ПРОСП.'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '30.08.2017'}],
#   'DAP': '18810177170714256645',
#   'DAPName': 'Постановление по видеофиксации №18810177170714256645 от 14.07.2017',
#   'DateDAP': '14.07.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 1500,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,732458',
#   'Longitude': '37,496129',
#   'OdpsKod': '1145519',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177170714256645","DateDAP":"14.07.2017","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":1500,"Uin":"18810177170714256645"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': 'cb570ea3-e68a-4648-aa95-4f7118fcdc34',
#   'VidNak': '2',
#   'VstupDate': '30.08.2017',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.09.2 - Превышение скорости движения ТС от 20 до 40 км/ч'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '08.07.2017 14:39:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   КИЕВСКОЕ ШОССЕ 33КМ 330М, ОСТАНОВКА ПОВОРОТ НА ТОЛСТОПАЛЬЦЕВО, В ЦЕНТР'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '04.09.2017'}],
#   'DAP': '18810177170720063632',
#   'DAPName': 'Постановление по видеофиксации №18810177170720063632 от 20.07.2017',
#   'DateDAP': '20.07.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 500,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,5800306459',
#   'Longitude': '37,2404658794',
#   'OdpsKod': '1145519',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177170720063632","DateDAP":"20.07.2017","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":500,"Uin":"18810177170720063632"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': '89d2c7dd-e699-4da9-af26-bb672faab113',
#   'VidNak': '2',
#   'VstupDate': '04.09.2017',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.09.2 - Превышение скорости движения ТС от 20 до 40 км/ч'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '19.06.2017 13:43:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   ЛЕНИНГРАДСКИЙ ПРОСП. д.14 к.1'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '06.08.2017'}],
#   'DAP': '18810177170622478153',
#   'DAPName': 'Постановление по видеофиксации №18810177170622478153 от 22.06.2017',
#   'DateDAP': '22.06.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 500,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,780244',
#   'Longitude': '37,577308',
#   'OdpsKod': '1145519',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177170622478153","DateDAP":"22.06.2017","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":500,"Uin":"18810177170622478153"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': 'b15b5dc1-b290-4a80-8d4b-c357cccce802',
#   'VidNak': '2',
#   'VstupDate': '06.08.2017',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.09.2 - Превышение скорости движения ТС от 20 до 40 км/ч'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '24.06.2017 19:31:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   РУБЛЕВСКОЕ Ш. д.14 к.1'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '15.08.2017'}],
#   'DAP': '18810177170701757373',
#   'DAPName': 'Постановление по видеофиксации №18810177170701757373 от 01.07.2017',
#   'DateDAP': '01.07.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 500,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,7390299999',
#   'Longitude': '37,434680',
#   'OdpsKod': '1145519',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177170701757373","DateDAP":"01.07.2017","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":500,"Uin":"18810177170701757373"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': '6c3fe5ff-cd5e-4398-8c98-91558f3d7130',
#   'VidNak': '2',
#   'VstupDate': '15.08.2017',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.17 ч.1.2 - Движение или остановка на полосе для маршрутных ТС в Москве или в Санкт-Петербурге'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '28.06.2017 19:49:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   ЛЕНИНСКИЙ ПРОСП.'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '19.08.2017'}],
#   'DAP': '18810177170704634493',
#   'DAPName': 'Постановление по видеофиксации №18810177170704634493 от 04.07.2017',
#   'DateDAP': '04.07.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 3000,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,654099',
#   'Longitude': '37,492814',
#   'OdpsKod': '1145519',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177170704634493","DateDAP":"04.07.2017","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":3000,"Uin":"18810177170704634493"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': '51d9f6a2-ea1f-4fe8-a4f1-ed9889414639',
#   'VidNak': '2',
#   'VstupDate': '19.08.2017',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.17 ч.1.2 - Движение или остановка на полосе для маршрутных ТС в Москве или в Санкт-Петербурге'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '29.06.2017 16:36:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   МОХОВАЯ д.15/1'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '21.08.2017'}],
#   'DAP': '18810177170706304598',
#   'DAPName': 'Постановление по видеофиксации №18810177170706304598 от 06.07.2017',
#   'DateDAP': '06.07.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 3000,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,7563209999',
#   'Longitude': '37,614136',
#   'OdpsKod': '1145519',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177170706304598","DateDAP":"06.07.2017","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":3000,"Uin":"18810177170706304598"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': '94ea1838-a741-45c3-9e8c-5cdf58e507bc',
#   'VidNak': '2',
#   'VstupDate': '21.08.2017',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.15.1 - Наруш.правил расп.т/с на пр.части без выезда на ст.встр.движ.,дв.по обоч.,пересечение колонны'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '23.06.2017 09:59:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   КУТУЗОВСКИЙ ПРОСП.'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '08.08.2017'}],
#   'DAP': '18810177170625591449',
#   'DAPName': 'Постановление по видеофиксации №18810177170625591449 от 25.06.2017',
#   'DateDAP': '25.06.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 1500,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,732458',
#   'Longitude': '37,496129',
#   'OdpsKod': '1145519',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177170625591449","DateDAP":"25.06.2017","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":1500,"Uin":"18810177170625591449"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': 'c38ce548-491f-4316-bc6e-8537e3b64968',
#   'VidNak': '2',
#   'VstupDate': '08.08.2017',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.09.2 - Превышение скорости движения ТС от 20 до 40 км/ч'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '23.07.2017 09:18:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   ФАД А-101, МОСКВА-РОСЛАВЛЬ, 37 КМ 300 М, МГО № 953'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '12.09.2017'}],
#   'DAP': '18810177170727543990',
#   'DAPName': 'Постановление по видеофиксации №18810177170727543990 от 27.07.2017',
#   'DateDAP': '27.07.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 500,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,492207',
#   'Longitude': '37,327406',
#   'OdpsKod': '1145519',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177170727543990","DateDAP":"27.07.2017","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":500,"Uin":"18810177170727543990"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': '2433c71e-60fd-4b9f-8e4e-a702d1cdb682',
#   'VidNak': '2',
#   'VstupDate': '12.09.2017',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.17 ч.1.2 - Движение или остановка на полосе для маршрутных ТС в Москве или в Санкт-Петербурге'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '20.06.2017 10:15:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   КУТУЗОВСКИЙ ПРОСП.'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '09.08.2017'}],
#   'DAP': '18810177170626059341',
#   'DAPName': 'Постановление по видеофиксации №18810177170626059341 от 26.06.2017',
#   'DateDAP': '26.06.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 3000,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,7347',
#   'Longitude': '37,508970',
#   'OdpsKod': '1145519',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177170626059341","DateDAP":"26.06.2017","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":3000,"Uin":"18810177170626059341"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': '67b468ed-046c-496e-870f-b3d094a4548d',
#   'VidNak': '2',
#   'VstupDate': '09.08.2017',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.17 ч.1.2 - Движение или остановка на полосе для маршрутных ТС в Москве или в Санкт-Петербурге'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '28.06.2017 19:50:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   ЛЕНИНСКИЙ ПРОСП.'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '19.08.2017'}],
#   'DAP': '18810177170704636232',
#   'DAPName': 'Постановление по видеофиксации №18810177170704636232 от 04.07.2017',
#   'DateDAP': '04.07.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 3000,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,6607300507',
#   'Longitude': '37,5052079558',
#   'OdpsKod': '1145519',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177170704636232","DateDAP":"04.07.2017","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":3000,"Uin":"18810177170704636232"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': '4a851a36-a36f-4304-b45f-b2e79fc670db',
#   'VidNak': '2',
#   'VstupDate': '19.08.2017',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.15.1 - Наруш.правил расп.т/с на пр.части без выезда на ст.встр.движ.,дв.по обоч.,пересечение колонны'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '09.07.2017 19:09:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   КУТУЗОВСКИЙ ПРОСП.'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '26.08.2017'}],
#   'DAP': '18810177170711191909',
#   'DAPName': 'Постановление по видеофиксации №18810177170711191909 от 11.07.2017',
#   'DateDAP': '11.07.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 1500,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,732458',
#   'Longitude': '37,496129',
#   'OdpsKod': '1145519',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177170711191909","DateDAP":"11.07.2017","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":1500,"Uin":"18810177170711191909"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': 'b1073a2e-e8ec-42c7-affa-4bf3691bf2fc',
#   'VidNak': '2',
#   'VstupDate': '26.08.2017',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.17 ч.1.2 - Движение или остановка на полосе для маршрутных ТС в Москве или в Санкт-Петербурге'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '28.06.2017 19:55:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   ЛЕНИНСКИЙ ПРОСП. д.75А'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '19.08.2017'}],
#   'DAP': '18810177170704643786',
#   'DAPName': 'Постановление по видеофиксации №18810177170704643786 от 04.07.2017',
#   'DateDAP': '04.07.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 3000,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,6864899999',
#   'Longitude': '37,543460',
#   'OdpsKod': '1145519',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177170704643786","DateDAP":"04.07.2017","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":3000,"Uin":"18810177170704643786"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': 'ab3af0bb-e0fe-493b-8288-0cf84893f1e5',
#   'VidNak': '2',
#   'VstupDate': '19.08.2017',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.09.2 - Превышение скорости движения ТС от 20 до 40 км/ч'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '28.06.2017 19:42:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   КИЕВСКОЕ Ш.'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '25.08.2017'}],
#   'DAP': '18810177170709732272',
#   'DAPName': 'Постановление по видеофиксации №18810177170709732272 от 09.07.2017',
#   'DateDAP': '09.07.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 500,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,600335',
#   'Longitude': '37,3215429999',
#   'OdpsKod': '1145519',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177170709732272","DateDAP":"09.07.2017","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":500,"Uin":"18810177170709732272"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': 'f7409900-c185-4364-b37e-20e776376c6b',
#   'VidNak': '2',
#   'VstupDate': '25.08.2017',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.17 ч.1.2 - Движение или остановка на полосе для маршрутных ТС в Москве или в Санкт-Петербурге'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '04.07.2017 21:57:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   МОХОВАЯ д.15/1'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '26.08.2017'}],
#   'DAP': '18810177170710622493',
#   'DAPName': 'Постановление по видеофиксации №18810177170710622493 от 10.07.2017',
#   'DateDAP': '10.07.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 3000,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,7563209999',
#   'Longitude': '37,614136',
#   'OdpsKod': '1145519',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177170710622493","DateDAP":"10.07.2017","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":3000,"Uin":"18810177170710622493"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': '91f0ebbe-75a9-4369-a31a-531607d50b4b',
#   'VidNak': '2',
#   'VstupDate': '26.08.2017',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.15.5 - Повторный выезд на сторону, предназначенную для встречного движения'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '03.07.2017 18:21:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   МОХОВАЯ д.7'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '19.08.2017'}],
#   'DAP': '18810177170705078772',
#   'DAPName': 'Постановление по видеофиксации №18810177170705078772 от 05.07.2017',
#   'DateDAP': '05.07.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 5000,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,752805',
#   'Longitude': '37,6112329999',
#   'OdpsKod': '1145519',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177170705078772","DateDAP":"05.07.2017","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":5000,"Uin":"18810177170705078772"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': '7ee45b6a-a069-42d6-a595-18a62b94e919',
#   'VidNak': '2',
#   'VstupDate': '19.08.2017',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.15.1 - Наруш.правил расп.т/с на пр.части без выезда на ст.встр.движ.,дв.по обоч.,пересечение колонны'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '22.07.2017 15:20:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   КУТУЗОВСКИЙ ПРОСП.'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '08.09.2017'}],
#   'DAP': '18810177170754399730',
#   'DAPName': 'Постановление по видеофиксации №18810177170754399730 от 23.07.2017',
#   'DateDAP': '23.07.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 1500,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,732458',
#   'Longitude': '37,496129',
#   'OdpsKod': '1145519',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177170754399730","DateDAP":"23.07.2017","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":1500,"Uin":"18810177170754399730"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': 'f03f9a77-c406-4280-a822-f67d040bd0af',
#   'VidNak': '2',
#   'VstupDate': '08.09.2017',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.17 ч.1.2 - Движение или остановка на полосе для маршрутных ТС в Москве или в Санкт-Петербурге'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '01.07.2017 11:18:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   МОХОВАЯ д.15/1'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '21.08.2017'}],
#   'DAP': '18810177170706312485',
#   'DAPName': 'Постановление по видеофиксации №18810177170706312485 от 06.07.2017',
#   'DateDAP': '06.07.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 3000,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,7563209999',
#   'Longitude': '37,614136',
#   'OdpsKod': '1145519',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177170706312485","DateDAP":"06.07.2017","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":3000,"Uin":"18810177170706312485"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': '4404e39c-99f8-445f-a11f-6886ef8d407b',
#   'VidNak': '2',
#   'VstupDate': '21.08.2017',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.15.1 - Наруш.правил расп.т/с на пр.части без выезда на ст.встр.движ.,дв.по обоч.,пересечение колонны'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '06.07.2017 22:10:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   КУТУЗОВСКИЙ ПРОСП.'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '23.08.2017'}],
#   'DAP': '18810177170708946155',
#   'DAPName': 'Постановление по видеофиксации №18810177170708946155 от 08.07.2017',
#   'DateDAP': '08.07.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 1500,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,732458',
#   'Longitude': '37,496129',
#   'OdpsKod': '1145519',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177170708946155","DateDAP":"08.07.2017","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":1500,"Uin":"18810177170708946155"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': 'fed5d338-7f4a-47bb-b13b-1fb55ae20e19',
#   'VidNak': '2',
#   'VstupDate': '23.08.2017',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.09.2 - Превышение скорости движения ТС от 20 до 40 км/ч'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '29.06.2017 12:02:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   РУБЛЕВСКОЕ Ш.'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '25.08.2017'}],
#   'DAP': '18810177170709835543',
# ...
#   'Type': 0,
#   'UID': '3d886d2a-f571-4b2c-bade-a5a037320239',
#   'VidNak': '2',
#   'VstupDate': '',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.09.2 - Превышение скорости движения ТС от 20 до 40 км/ч'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '02.03.2018 14:52:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   РУБЛЕВСКОЕ Ш.'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'УГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'}],
#   'DAP': '18810177180302290675',
#   'DAPName': 'Постановление по видеофиксации №18810177180302290675 от 02.03.2018',
#   'DateDAP': '02.03.2018',
#   'DiscountDate': '22.03.2018',
#   'DiscountSize': '250',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 0,
#   'FineSum': 500,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,7420588260',
#   'Longitude': '37,4277336895',
#   'OdpsKod': '1145000',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177180302290675","DateDAP":"02.03.2018","ODPS":"УГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":500,"Uin":"18810177180302290675"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': 'b8c52585-6725-4955-b521-51ca851b8968',
#   'VidNak': '2',
#   'VstupDate': '',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.09.2 - Превышение скорости движения ТС от 20 до 40 км/ч'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '03.03.2018 17:50:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   ЛЕНИНГРАДСКИЙ ПРОСП.'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'УГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'}],
#   'DAP': '18810177180303366071',
#   'DAPName': 'Постановление по видеофиксации №18810177180303366071 от 03.03.2018',
#   'DateDAP': '03.03.2018',
#   'DiscountDate': '23.03.2018',
#   'DiscountSize': '250',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 0,
#   'FineSum': 500,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,8029209999',
#   'Longitude': '37,522291',
#   'OdpsKod': '1145000',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177180303366071","DateDAP":"03.03.2018","ODPS":"УГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":500,"Uin":"18810177180303366071"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': '86a55eb0-1782-4709-a004-c4485e2def88',
#   'VidNak': '2',
#   'VstupDate': '',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.17 ч.1.2 - Движение или остановка на полосе для маршрутных ТС в Москве или в Санкт-Петербурге'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '01.03.2018 11:15:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   МОХОВАЯ'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'УГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'}],
#   'DAP': '18810177180305047267',
#   'DAPName': 'Постановление по видеофиксации №18810177180305047267 от 05.03.2018',
#   'DateDAP': '05.03.2018',
#   'DiscountDate': '26.03.2018',
#   'DiscountSize': '1500',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 0,
#   'FineSum': 3000,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,7563209999',
#   'Longitude': '37,614136',
#   'OdpsKod': '1145000',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177180305047267","DateDAP":"05.03.2018","ODPS":"УГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":3000,"Uin":"18810177180305047267"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': '4194d5c8-7aac-4ae6-b16b-e51f6d2acd32',
#   'VidNak': '2',
#   'VstupDate': '',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.09.2 - Превышение скорости движения ТС от 20 до 40 км/ч'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '05.03.2018 22:10:00'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'МОСКВА Г.   НОВЫЙ АРБАТ д.28'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'УГИБДД ГУ МВД России по г.Москве'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'}],
#   'DAP': '18810177180306024368',
#   'DAPName': 'Постановление по видеофиксации №18810177180306024368 от 06.03.2018',
#   'DateDAP': '06.03.2018',
#   'DiscountDate': '26.03.2018',
#   'DiscountSize': '250',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 0,
#   'FineSum': 500,
#   'HasAdditionalActions': False,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55,7526856396',
#   'Longitude': '37,5852088630',
#   'OdpsKod': '1145000',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"18810177180306024368","DateDAP":"06.03.2018","ODPS":"УГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":500,"Uin":"18810177180306024368"}',
#   'Sts': '7741525886',
#   'Type': 0,
#   'UID': 'b5c05e73-cac2-405d-a1b5-e5a7f420afc7',
#   'VidNak': '2',
#   'VstupDate': '',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.16.5 Нарушение, предусмотренное частью 4 настоящей статьи, совершенное в городе федерального значения Москве или Санкт-Петербурге'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'г. Москва, Тверская улица, 4'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '01.02.2018 16:28:43'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'г. Москва, Тверская улица, 4'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'МАДИ'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'Леонид Эдуардович'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'}],
#   'DAP': '0356043010118020600026773',
#   'DAPName': 'Постановление по делу об административном правонарушении №0356043010118020600026773 от 06.02.2018',
#   'DateDAP': '06.02.2018',
#   'DiscountDate': '',
#   'DiscountSize': None,
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 0,
#   'FineSum': 3000,
#   'HasAdditionalActions': True,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55.75806722',
#   'Longitude': '37.61338083',
#   'OdpsKod': '1145597',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"0356043010118020600026773","DateDAP":"06.02.2018","ODPS":"МАДИ","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707821043","ShKbk":"78211630020018000140","ShKpp":"770701001","ShOkato":"45382000","ShPoluchName":"УФК по г. Москве (МАДИ л\\/с 047 322 241 50)","Sum":3000,"Uin":"0356043010118020600026773"}',
#   'Sts': '7741525886',
#   'Type': 2,
#   'UID': '41d67e8b-79dd-413f-a5c1-f696689c60e9',
#   'VidNak': '2',
#   'VstupDate': '',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.16.5 Нарушение, предусмотренное частью 4 настоящей статьи, совершенное в городе федерального значения Москве или Санкт-Петербурге'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'г. Москва, Тверская улица, 4'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '20.02.2018 11:44:39'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'г. Москва, Тверская улица, 4'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'МАДИ'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'Леонид Эдуардович'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'}],
#   'DAP': '0356043010118030100013940',
#   'DAPName': 'Постановление по делу об административном правонарушении №0356043010118030100013940 от 01.03.2018',
#   'DateDAP': '01.03.2018',
#   'DiscountDate': '21.03.2018',
#   'DiscountSize': '1500',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 0,
#   'FineSum': 3000,
#   'HasAdditionalActions': True,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55.75807472',
#   'Longitude': '37.61351972',
#   'OdpsKod': '1145597',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"0356043010118030100013940","DateDAP":"01.03.2018","ODPS":"МАДИ","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707821043","ShKbk":"78211630020018000140","ShKpp":"770701001","ShOkato":"45382000","ShPoluchName":"УФК по г. Москве (МАДИ л\\/с 047 322 241 50)","Sum":3000,"Uin":"0356043010118030100013940"}',
#   'Sts': '7741525886',
#   'Type': 2,
#   'UID': '28428a83-b18a-4894-a9a8-781a01fc21bc',
#   'VidNak': '2',
#   'VstupDate': '',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.16.5 Нарушение, предусмотренное частью 4 настоящей статьи, совершенное в городе федерального значения Москве или Санкт-Петербурге'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'г. Москва, ул. Охотный Ряд, д. 2'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '02.12.2017 10:31:12'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'г. Москва, ул. Охотный Ряд, д. 2'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'МАДИ'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'Леонид Эдуардович'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '17.01.2018'}],
#   'DAP': '0356043010117120400019385',
#   'DAPName': 'Постановление по делу об административном правонарушении №0356043010117120400019385 от 04.12.2017',
#   'DateDAP': '04.12.2017',
#   'DiscountDate': '',
#   'DiscountSize': None,
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 0,
#   'FineSum': 3000,
#   'HasAdditionalActions': True,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55.75707889',
#   'Longitude': '37.61542111',
#   'OdpsKod': '1145597',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"0356043010117120400019385","DateDAP":"04.12.2017","ODPS":"МАДИ","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707821043","ShKbk":"78211630020018000140","ShKpp":"770701001","ShOkato":"45382000","ShPoluchName":"УФК по г. Москве (МАДИ л\\/с 047 322 241 50)","Sum":3000,"Uin":"0356043010117120400019385"}',
#   'Sts': '7741525886',
#   'Type': 2,
#   'UID': '3b901a41-d137-4ba3-a0f9-9511c2af0f4a',
#   'VidNak': '2',
#   'VstupDate': '17.01.2018',
#   'Vu': ''},
#  {'AdminOffensesTypeText': 'Штраф',
#   'AmountToPay': None,
#   'ApnDetail': [{'AttrId': 'StAP',
#     'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения',
#     'Value': '12.16.5 Нарушение, предусмотренное частью 4 настоящей статьи, совершенное в городе федерального значения Москве или Санкт-Петербурге'},
#    {'AttrId': 'MestoDAP',
#     'Name': 'Место составления документа',
#     'Value': 'г. Москва, Тверская улица, 3'},
#    {'AttrId': 'DatNar',
#     'Name': 'Дата и время нарушения',
#     'Value': '13.09.2017 21:28:18'},
#    {'AttrId': 'MestoNar',
#     'Name': 'Место нарушения',
#     'Value': 'г. Москва, Тверская улица, 3'},
#    {'AttrId': 'OdpsName',
#     'Name': 'Орган власти, выявивший нарушение',
#     'Value': 'МАДИ'},
#    {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'Леонид Эдуардович'},
#    {'AttrId': 'GRZNarush',
#     'Name': 'Транспортное средство',
#     'Value': 'С700*****'},
#    {'AttrId': 'SentToFssp', 'Name': 'Дело отправлено в ФССП', 'Value': 'Да'},
#    {'AttrId': 'FsspOtd', 'Name': 'Отдел ФССП', 'Value': 'МОСП по ВАШ №1'},
#    {'AttrId': 'SentToFsspDate',
#     'Name': 'Дата отправки в ФССП',
#     'Value': '11.01.2018'},
#    {'AttrId': 'ClosedInFssp', 'Name': 'Дело закрыто в ФССП', 'Value': 'Да'},
#    {'AttrId': 'EffDate',
#     'Name': 'Дата вступления постановления в силу',
#     'Value': '31.10.2017'}],
#   'DAP': '0356043010117091400005435',
#   'DAPName': 'Протокол по делу 20.25 №0356043010117091400005435 от 14.09.2017',
#   'DateDAP': '14.09.2017',
#   'DiscountDate': '',
#   'DiscountSize': '',
#   'DiscountSizeAmountToPaySum': None,
#   'FineStatus': 1,
#   'FineSum': 3000,
#   'HasAdditionalActions': True,
#   'HasPhoto': True,
#   'IsFine': True,
#   'Latitude': '55.75762361',
#   'Longitude': '37.61338444',
#   'OdpsKod': '1145597',
#   'PayedAmountSum': None,
#   'PaymentId': '',
#   'Sh': '{"DAP":"0356043010117091400005435","DateDAP":"14.09.2017","ODPS":"МАДИ","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707821043","ShKbk":"78211630020018000140","ShKpp":"770701001","ShOkato":"45382000","ShPoluchName":"УФК по г. Москве (МАДИ л\\/с 047 322 241 50)","Sum":3000,"Uin":"0356043010117091400005435"}',
#   'Sts': '7741525886',
#   'Type': 2,
#   'UID': 'fb76a844-130a-4f69-97d5-f28fe8d81468',
#   'VidNak': '2',
#   'VstupDate': '31.10.2017',
#   'Vu': ''}]

# %%
type(fines_values)
# Out:
# list

# %%
fines_prepared_data = [
    {
        'Name': data['ApnDetail'][0] ['Value'].replace('\t', ' - '),
        'Place': data['ApnDetail'][3]['Value'],
        'FineSum': data['FineSum']
    }
    for data in fines_values
]
fines_prepared_data[0]
# Out:
# {'Name': '12.17 ч.1.2 - Движение или остановка на полосе для маршрутных ТС в Москве или в Санкт-Петербурге',
#  'Place': 'МОСКВА Г.   МОХОВАЯ д.15/1',
#  'FineSum': 3000}

# %%
df = fines_df = pd.DataFrame(fines_prepared_data)
df
# Out:
#                                                   Name  \
# 0    12.17 ч.1.2 - Движение или остановка на полосе...
# 1    12.09.2 - Превышение скорости движения ТС от 2...
# 2    12.9.6 - Повторное превышение скорости на 40-6...
# 3    12.15.1 - Наруш.правил расп.т/с на пр.части бе...
# 4    12.9.6 - Повторное превышение скорости на 40-6...
# ..                                                 ...
# 830  12.09.2 - Превышение скорости движения ТС от 2...
# 831  12.16.5 Нарушение, предусмотренное частью 4 на...
# 832  12.16.5 Нарушение, предусмотренное частью 4 на...
# 833  12.16.5 Нарушение, предусмотренное частью 4 на...
# 834  12.16.5 Нарушение, предусмотренное частью 4 на...
#
#                                         Place  FineSum
# 0                  МОСКВА Г.   МОХОВАЯ д.15/1     3000
# 1      А/Д М-9 "БАЛТИЯ", 24КМ+750М, ИЗ МОСКВЫ      500
# 2              МОСКВА Г.   РУБЛЕВСКОЕ Ш. д.79     2000
# 3              МОСКВА Г.   КУТУЗОВСКИЙ ПРОСП.     1500
# 4              МОСКВА Г.   НОВЫЙ АРБАТ д.36/9     2000
# ..                                        ...      ...
# 830              МОСКВА Г.   НОВЫЙ АРБАТ д.28      500
# 831              г. Москва, Тверская улица, 4     3000
# 832              г. Москва, Тверская улица, 4     3000
# 833          г. Москва, ул. Охотный Ряд, д. 2     3000
# 834              г. Москва, Тверская улица, 3     3000
#
# [835 rows x 3 columns]

# %%
# Out:
#                                                   Name  \
# 0    12.17 ч.1.2 - Движение или остановка на полосе...
# 1    12.09.2 - Превышение скорости движения ТС от 2...
# 2    12.9.6 - Повторное превышение скорости на 40-6...
# 3    12.15.1 - Наруш.правил расп.т/с на пр.части бе...
# 4    12.9.6 - Повторное превышение скорости на 40-6...
# ..                                                 ...
# 830  12.09.2 - Превышение скорости движения ТС от 2...
# 831  12.16.5 Нарушение, предусмотренное частью 4 на...
# 832  12.16.5 Нарушение, предусмотренное частью 4 на...
# 833  12.16.5 Нарушение, предусмотренное частью 4 на...
# 834  12.16.5 Нарушение, предусмотренное частью 4 на...
#
#                                         Place  FineSum
# 0                  МОСКВА Г.   МОХОВАЯ д.15/1     3000
# 1      А/Д М-9 "БАЛТИЯ", 24КМ+750М, ИЗ МОСКВЫ      500
# 2              МОСКВА Г.   РУБЛЕВСКОЕ Ш. д.79     2000
# 3              МОСКВА Г.   КУТУЗОВСКИЙ ПРОСП.     1500
# 4              МОСКВА Г.   НОВЫЙ АРБАТ д.36/9     2000
# ..                                        ...      ...
# 830              МОСКВА Г.   НОВЫЙ АРБАТ д.28      500
# 831              г. Москва, Тверская улица, 4     3000
# 832              г. Москва, Тверская улица, 4     3000
# 833          г. Москва, ул. Охотный Ряд, д. 2     3000
# 834              г. Москва, Тверская улица, 3     3000
#
# [835 rows x 3 columns]

# %%
summary = df.groupby('Name')['FineSum'].agg(['count', 'sum'])
summary
# Out:
#                                                     count     sum
# Name
# 12.09.2 - Превышение скорости движения ТС от 20...    361  180500
# 12.09.3 - Превышение скорости движения ТС от 40...      7    7000
# 12.15.1 - Наруш.правил расп.т/с на пр.части без...     95  142500
# 12.15.5 - Повторный выезд на сторону, предназна...     21  105000
# 12.16.1 - Несоблюдение требований знаков или ра...      8    4000
# ...                                                   ...     ...
# 12.17 ч.1.2 - Движение или остановка на полосе ...    212  636000
# 12.19 ч.6 - Стоянка, остановка ТС на проезжей ч...      3    9000
# 12.9.6 - Повторное превышение скорости на 40-60...     94  188000
# 12.9.7 - Повторное превышение скорости на 60-80...     17   85000
# 8.14.2  - Неуплата за размещение транспортного ...      1    2500
#
# [12 rows x 2 columns]

# %%
summary.sort_values(['count'], ascending=False)
# Out:
#                                                     count     sum
# Name
# 12.09.2 - Превышение скорости движения ТС от 20...    361  180500
# 12.17 ч.1.2 - Движение или остановка на полосе ...    212  636000
# 12.15.1 - Наруш.правил расп.т/с на пр.части без...     95  142500
# 12.9.6 - Повторное превышение скорости на 40-60...     94  188000
# 12.15.5 - Повторный выезд на сторону, предназна...     21  105000
# ...                                                   ...     ...
# 12.16.1 - Несоблюдение требований знаков или ра...      8    4000
# 12.09.3 - Превышение скорости движения ТС от 40...      7    7000
# 12.19 ч.6 - Стоянка, остановка ТС на проезжей ч...      3    9000
# 12.16.2 - Поворот налево или разворот в нарушен...      1    1000
# 8.14.2  - Неуплата за размещение транспортного ...      1    2500
#
# [12 rows x 2 columns]

# %%
summary.sum()
# Out:
# count        835
# sum      1405500
# dtype: int64

# %%
total = pd.Series(
    summary.sum(),
    name='Full summary'
)
total
# Out:
# count        835
# sum      1405500
# Name: Full summary, dtype: int64

# %%
pd.concat([summary, total])
# Out:
#                                                     count       sum          0
# 12.09.2 - Превышение скорости движения ТС от 20...  361.0  180500.0        NaN
# 12.09.3 - Превышение скорости движения ТС от 40...    7.0    7000.0        NaN
# 12.15.1 - Наруш.правил расп.т/с на пр.части без...   95.0  142500.0        NaN
# 12.15.5 - Повторный выезд на сторону, предназна...   21.0  105000.0        NaN
# 12.16.1 - Несоблюдение требований знаков или ра...    8.0    4000.0        NaN
# ...                                                   ...       ...        ...
# 12.9.6 - Повторное превышение скорости на 40-60...   94.0  188000.0        NaN
# 12.9.7 - Повторное превышение скорости на 60-80...   17.0   85000.0        NaN
# 8.14.2  - Неуплата за размещение транспортного ...    1.0    2500.0        NaN
# count                                                 NaN       NaN      835.0
# sum                                                   NaN       NaN  1405500.0
#
# [14 rows x 3 columns]

# %%
pd.concat([summary, total.to_frame().T])
# Out:
#                                                     count      sum
# 12.09.2 - Превышение скорости движения ТС от 20...    361   180500
# 12.09.3 - Превышение скорости движения ТС от 40...      7     7000
# 12.15.1 - Наруш.правил расп.т/с на пр.части без...     95   142500
# 12.15.5 - Повторный выезд на сторону, предназна...     21   105000
# 12.16.1 - Несоблюдение требований знаков или ра...      8     4000
# ...                                                   ...      ...
# 12.19 ч.6 - Стоянка, остановка ТС на проезжей ч...      3     9000
# 12.9.6 - Повторное превышение скорости на 40-60...     94   188000
# 12.9.7 - Повторное превышение скорости на 60-80...     17    85000
# 8.14.2  - Неуплата за размещение транспортного ...      1     2500
# Full summary                                          835  1405500
#
# [13 rows x 2 columns]
